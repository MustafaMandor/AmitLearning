# %%
# DO NOT RUN THIS CODE !!

# %%
while True:
    print("You are stuck in an infinite loop,Good luck Getting out")
# Out:
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# You are stuck in an infinite loop,Good luck Getting out
# ...
